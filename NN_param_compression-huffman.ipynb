# %%
#  Steps of the work:

# Make a model with accessible parameters using TensorFlow 2.x
# Write an entropy loss and add it to the network parameters for training.
# Train a model by jointly optimizing its loss (e.g. cross entropy for classification) and the entropy for compressability.
# Compress the model parameters using Huffman coding.
# Analyze the results and trade-off between accuracy and compressability.
# Write a model wrapper that can read and write the compressed parameters.

# Notes:

# Can be started on simple datasets like MNIST.
# Can start from simple MLP NNs. And then extend to convs. The implementation should be generic enough so that it can support any layer.
# Bonus: add support for normalization layers: batch norm, instance norm, etc.

# %%
# Load MNIST data set

from tensorflow.keras.datasets import mnist
train_set, test_set = mnist.load_data()

# %%
# generate a simple NN model

from tensorflow.keras.layers import Dense, Input, Flatten
from tensorflow.keras.models import Model
import tensorflow as tf
from tensorflow import keras
import numpy as np

    
kernel_initializer = 'he_normal'
activation = "relu"

def get_model(chs=128):
    shape=(28,28,1)
    
    inputs = Input(shape)
    layer = Flatten()(inputs)
    layer = Dense(units=chs*2, activation=activation, kernel_initializer=kernel_initializer)(layer)
    layer = Dense(units=chs, activation=activation, kernel_initializer=kernel_initializer)(layer)
    output = Dense(10, activation='linear', use_bias=True, kernel_initializer=kernel_initializer)(layer)

    model = Model(inputs, output)
    return model

# %%
#     To estimate the histogram, we first remove outliers in the
# activations if the samples are outside the range [μ−3σ; μ+3σ]
from histogram import calculate_histogram, test_histogram, calculate_histogram_range

def calculate_entropy(variables, eps=0.0):
    min_h, max_h = calculate_histogram_range(variables)
    flat_vars = tf.reshape(variables, (-1,1))    
    hist = calculate_histogram(flat_vars, min_h, max_h)
    
    probs = hist / tf.reduce_sum(hist)
    entropy = -tf.reduce_sum(probs * tf.experimental.numpy.log2(probs+eps))
    return entropy, (min_h, max_h)

class CompressibleNN(keras.Model):
    def __init__(self, net_model):
        super(CompressibleNN, self).__init__()
        self.net_model = net_model
        self.CE_loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

    def call(self, inputs):
        return self.net_model(inputs)
    
    def entropy_loss(self, inputs):
        entropy = 0
        
        for l in self.net_model.layers:
            if isinstance(l, keras.layers.Dense):
                for v in l.trainable_variables:
                    v_entropy, v_range = calculate_entropy(v)
                    entropy += v_entropy
        return entropy    
    
    def train_step(self, input):
        images = input[0]
        labels = input[1]

        with tf.GradientTape() as tape:
            output = self.net_model(images)
            loss =  self.entropy_loss(images)
            regularization_loss = self.regularization_loss(images)

        # Get the gradients w.r.t the loss
#         gradient = tape.gradient(loss, self.net_model.trainable_variables)
        gradient_reg = tape.gradient(regularization_loss, self.net_model.trainable_variables)
        # Update the weights using the generator optimizer
        self.optimizer.apply_gradients(
            zip(gradient_reg, self.net_model.trainable_variables)
        )
        return {"regularization loss": regularization_loss}
#         return {"loss": loss}
        
model = get_model()
compNN = CompressibleNN(model)
optimizer = tf.optimizers.Adam(learning_rate=1e-3, beta_1=0.9)
compNN.compile(optimizer, loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True))

# %%
from histogram import visualize_histogram
variables=model.layers[3].variables[0]
visualize_histogram(variables)

# %%
from histogram import visualize_histogram
variables=model.layers[3].variables[0]
visualize_histogram(variables)

# %%
# train the model
tf.config.run_functions_eagerly(True)
# loss needs to be decreased during training
compNN.fit(x=train_set[0], y=train_set[1], epochs=1, batch_size=32)
# Out:
#   25/1875 [..............................] - ETA: 18:59 - regularization loss: 0.1705
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_333/3955768440.py in ?()
#       1 # train the model
#       2 tf.config.run_functions_eagerly(True)
#       3 # loss needs to be decreased during training
# ----> 4 compNN.fit(x=train_set[0], y=train_set[1], epochs=1, batch_size=32)
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in ?(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1681                             batch_size=batch_size,
#    1682                             _r=1,
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#    1688                             # No error, now safe to assign to logs.
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in ?(iterator)
#    1282             def train_function(iterator):
#    1283                 """Runs a training execution with a single step."""
# -> 1284                 return step_function(self, iterator)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in ?(model, iterator)
#    1264                 run_step = tf.function(
#    1265                     run_step, jit_compile=True, reduce_retracing=True
#    1266                 )
#    1267             data = next(iterator)
# -> 1268             outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1269             outputs = reduce_per_replica(
#    1270                 outputs,
#    1271                 self.distribute_strategy,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in ?(***failed resolving arguments***)
#    1312       # tf.distribute supports Eager functions, so AutoGraph should not be
#    1313       # applied when the caller is also in Eager mode.
#    1314       fn = autograph.tf_convert(
#    1315           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1316       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in ?(self, fn, args, kwargs)
#    2891     _require_cross_replica_or_default_context_extended(self)
#    2892     if kwargs is None:
#    2893       kwargs = {}
#    2894     with self._container_strategy().scope():
# -> 2895       return self._call_for_each_replica(fn, args, kwargs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in ?(self, fn, args, kwargs)
#    3694   def _call_for_each_replica(self, fn, args, kwargs):
#    3695     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3696       return fn(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in ?(*args, **kwargs)
#     593   def wrapper(*args, **kwargs):
#     594     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 595       return func(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in ?(data)
#    1248             def run_step(data):
# -> 1249                 outputs = model.train_step(data)
#    1250                 # Ensure counter is updated only if `train_step` succeeds.
#    1251                 with tf.control_dependencies(_minimum_control_deps(outputs)):
#    1252                     model._train_counter.assign_add(1)
#
# /tmp/ipykernel_333/3823865116.py in ?(self, input)
#      56         labels = input[1]
#      57
#      58         with tf.GradientTape() as tape:
#      59             output = self.net_model(images)
# ---> 60             loss =  self.entropy_loss(images)
#      61             regularization_loss = self.regularization_loss(images)
#      62
#      63         # Get the gradients w.r.t the loss
#
# /tmp/ipykernel_333/3823865116.py in ?(self, inputs)
#      34
#      35         for l in self.net_model.layers:
#      36             if isinstance(l, keras.layers.Dense):
#      37                 for v in l.trainable_variables:
# ---> 38                     v_entropy, v_range = calculate_entropy(v)
#      39                     entropy += v_entropy
#      40         return entropy
#
# /tmp/ipykernel_333/3823865116.py in ?(variables, eps)
#       5 def calculate_entropy(variables, eps=0.0):
#       6     min_h, max_h = calculate_histogram_range(variables)
#       7     flat_vars = tf.reshape(variables, (-1,1))
# ----> 8     hist = calculate_histogram(flat_vars, min_h, max_h)
#       9
#      10     probs = hist / tf.reduce_sum(hist)
#      11     entropy = -tf.reduce_sum(probs * tf.experimental.numpy.log2(probs+eps))
#
# /workspace/histogram.py in ?(variables, min_h, max_h)
#      37 def weight(xk, t, nbins):
#      38     xk = tf.cast(xk, tf.float32)  # Cast xk to float32
#      39     t = tf.cast(t, tf.float32)  # Cast t to float32
# ---> 40     xk = tf.abs(xk - t) # Compute the absolute difference element-wise
#      41 #     print(xk)
#      42     mask = tf.less_equal(xk, 1)  # Create a boolean mask for elements <= 1
#      43     w = tf.where(mask, xk, tf.zeros_like(xk))  # Use the mask to select elements or zeros
#
# /workspace/histogram.py in ?(variables, min_h, max_h)
#      15 def calculate_histogram_range(variables, scale = 3):
#      16     std = tf.math.reduce_variance(variables)**0.5
#      17     if std==0.0:
#      18         std = 1.0
# ---> 19     mean = tf.math.reduce_mean(variables)
#      20     return mean - std*scale, mean + std*scale
#
# /workspace/histogram.py in ?(xk, t, nbins)
#      30     xk = tf.reshape(variables, [-1, 1])  # Reshape variables to a column vector (65536, 1)
#      31     t = tf.linspace(0, nbins - 1, nbins)
#      32     w = weight(xk, t, nbins) # (65536, 256)
#      33     deltas = tf.reduce_sum(w, axis=0)  # Compute the sum along the first axis (j)
# ---> 34     deltas = tf.reshape(deltas, (-1, 1)) # (256, 1)?
#      35
#      36     # test if values add to 1 for each weight
#      37     # print(tf.reduce_sum(w, axis=1))
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1173
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
#    1176         return dispatch_target(*args, **kwargs)
# -> 1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179         # TypeError, when given unexpected types.  So we need to catch both.
#    1180         result = dispatch(op_dispatch_handler, args, kwargs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/array_ops.py in ?(condition, x, y, name)
#    4980       condition = ops.convert_to_tensor(
#    4981           condition, preferred_dtype=dtypes.bool, name="condition")
#    4982       return gen_array_ops.where(condition=condition, name=name)
#    4983   elif x is not None and y is not None:
# -> 4984     return gen_math_ops.select_v2(condition=condition, t=x, e=y, name=name)
#    4985   else:
#    4986     raise ValueError("x and y must both be non-None or both be None.")
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_math_ops.py in ?(condition, t, e, name)
#    9580         _ctx, "SelectV2", name, condition, t, e)
#    9581       return _result
#    9582     except _core._NotOkStatusException as e:
#    9583       _ops.raise_from_not_ok_status(e, name)
# -> 9584     except _core._FallbackException:
#    9585       pass
#    9586     try:
#    9587       return select_v2_eager_fallback(
#
# KeyboardInterrupt:

# %%
# test performance
res = model(test_set[0])
print("test acc: ", 100*(np.argmax(res, axis=1)==test_set[1]).mean())
# Out:
# test acc:  96.02000000000001

# %%
# test performance with entropy_loss
res = model(test_set[0])
print("test acc: ", 100*(np.argmax(res, axis=1)==test_set[1]).mean())
# Out:
# test acc:  96.61

# %%
 17.7708
 17.7171
 17.6588
